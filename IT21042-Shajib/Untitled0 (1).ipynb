# %%
import tensorflow as tf

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/bhavikjikadara/dog-and-cat-classification-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: shajibb
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/bhavikjikadara/dog-and-cat-classification-dataset
# ...
# 100%|██████████| 775M/775M [00:11<00:00, 70.3MB/s]

# %%
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D,BatchNormalization,Dropout
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
cnn = Sequential()

# %%
cnn.add(Conv2D(32,(3,3),input_shape=(256,256,3),activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Conv2D(64,(3,3),activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Conv2D(128,(3,3),activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Conv2D(256,(3,3),activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))
cnn.add(Flatten())
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(Dense(128,activation='relu'))
cnn.add(Dropout(0.1))
cnn.add(Dense(64,activation='relu'))
cnn.add(Dropout(0.1))
cnn.add(Dense(32,activation='relu'))
cnn.add(Dropout(0.1))
cnn.add(Dense(16,activation='relu'))
cnn.add(Dropout(0.1))
cnn.add(Dense(8,activation='relu'))
cnn.add(Dropout(0.1))
cnn.add(Dense(4,activation='relu'))
cnn.add(Dropout(0.1))
cnn.add(Dense(2,activation='relu'))
cnn.add(Dropout(0.1))
cnn.add(Dense(1,activation='sigmoid'))

# %%
cnn.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        "/content/dog-and-cat-classification-dataset/PetImages",
        target_size=(256,256),
        batch_size=32,
        class_mode='binary')

test_generator = test_datagen.flow_from_directory(
        "/content/dog-and-cat-classification-dataset/PetImages",
        target_size=(256,256),
        batch_size=32,
        class_mode='binary')

cnn.fit(
        train_generator,
        epochs=100,
        validation_data=test_generator,
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2060166694.py in <cell line: 0>()
# ----> 1 train_datagen = ImageDataGenerator(
#       2         rescale=1./255,
#       3         shear_range=0.2,
#       4         zoom_range=0.2,
#       5         horizontal_flip=True)
#
# NameError: name 'ImageDataGenerator' is not defined

# %%
from keras.preprocessing import image
import numpy as np

# %%
img= image.load_img("/content/cats-and-dogs-image-classification/test/dogs/dog_59.jpg",target_size=(256,256))

# %%
img=image.img_to_array(img)

# %%
img=np.expand_dims(img,axis=0)

# %%
p=cnn.predict(img)
print(p)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.49921432]]

# %%
if p[0][0]<0.5:
   print("cat")
else:
   print("dog")
